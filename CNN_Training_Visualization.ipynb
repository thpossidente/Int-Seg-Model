# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
loss = pd.read_csv("storage_means_loss1.csv")
acc = pd.read_csv("storage_means_acc1.csv")

# %%
x_axis = range(25)

plt.figure(1)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("2*2 Submatrix Pattern Size, 0% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[0,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[1,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[2,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("2*2 Submatrix Pattern Size, 10% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[3,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[4,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[5,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')


plt.figure(2)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("2*2 Submatrix Pattern Size, 20% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[6,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[7,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[8,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("2*2 Submatrix Pattern Size, 30% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[9,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[10,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[11,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')



plt.figure(3)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("2*2 Submatrix Pattern Size, 40% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[12,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[13,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[14,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("2*2 Submatrix Pattern Size, 50% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[15,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[16,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[17,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

# %%
x_axis = range(25)

plt.figure(1)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("4*4 Submatrix Pattern Size, 0% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[18,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[19,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[20,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("4*4 Submatrix Pattern Size, 10% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[21,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[22,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[23,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')


plt.figure(2)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("4*4 Submatrix Pattern Size, 20% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[24,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[25,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[26,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("4*4 Submatrix Pattern Size, 30% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[27,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[28,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[29,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')



plt.figure(3)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("4*4 Submatrix Pattern Size, 40% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[30,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[31,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[32,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("4*4 Submatrix Pattern Size, 50% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[33,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[34,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[35,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

# %%
x_axis = range(25)

plt.figure(1)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("8*8 Submatrix Pattern Size, 0% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[36,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[37,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[38,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("8*8 Submatrix Pattern Size, 10% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[39,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[40,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[41,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')


plt.figure(2)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("8*8 Submatrix Pattern Size, 20% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[42,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[43,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[44,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("8*8 Submatrix Pattern Size, 30% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[45,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[46,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[47,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')



plt.figure(3)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("8*8 Submatrix Pattern Size, 40% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[48,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[49,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[50,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("8*8 Submatrix Pattern Size, 50% Noise", fontsize = 'small')
plt.plot(x_axis, loss.iloc[51,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, loss.iloc[52,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, loss.iloc[53,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'upper right', fontsize = 'small')

# %%
x_axis = range(25)

plt.figure(1)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("2*2 Submatrix Pattern Size, 0% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[0,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[1,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[2,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("2*2 Submatrix Pattern Size, 10% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[3,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[4,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[5,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')


plt.figure(2)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("2*2 Submatrix Pattern Size, 20% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[6,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[7,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[8,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("2*2 Submatrix Pattern Size, 30% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[9,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[10,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[11,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')



plt.figure(3)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("2*2 Submatrix Pattern Size, 40% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[12,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[13,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[14,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("2*2 Submatrix Pattern Size, 50% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[15,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[16,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[17,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

# %%
x_axis = range(25)

plt.figure(1)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("4*4 Submatrix Pattern Size, 0% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[18,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[19,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[20,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("2*2 Submatrix Pattern Size, 10% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[21,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[22,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[23,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')


plt.figure(2)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("4*4 Submatrix Pattern Size, 20% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[24,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[25,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[26,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("4*4 Submatrix Pattern Size, 30% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[27,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[28,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[29,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')



plt.figure(3)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("4*4 Submatrix Pattern Size, 40% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[30,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[31,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[32,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("4*4 Submatrix Pattern Size, 50% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[33,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[34,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[35,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

# %%
x_axis = range(25)

plt.figure(1)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("8*8 Submatrix Pattern Size, 0% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[36,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[37,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[38,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("8*8 Submatrix Pattern Size, 10% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[39,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[40,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[41,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')


plt.figure(2)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("8*8 Submatrix Pattern Size, 20% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[42,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[43,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[44,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("8*8 Submatrix Pattern Size, 30% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[45,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[46,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[47,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')



plt.figure(3)

plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("8*8 Submatrix Pattern Size, 40% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[48,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[49,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[50,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("8*8 Submatrix Pattern Size, 50% Noise", fontsize = 'small')
plt.plot(x_axis, acc.iloc[51,3:], 'r', label = "2*2 RF Size")
plt.plot(x_axis, acc.iloc[52,3:], 'b', label = "4*4 RF Size")
plt.plot(x_axis, acc.iloc[53,3:], 'g', label = "8*8 RF Size")
plt.legend(loc = 'lower right', fontsize = 'small')
